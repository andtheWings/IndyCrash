# %%
import numpy as np
import pandas as pd
import matplotlib

# %% [markdown]
# # Import Data

# %%
# Obtain from https://hub.mph.in.gov/dataset/aries-crash-data-2007-2017/resource/911880b1-d0bb-4168-a5c1-a52dcc291445

raw_df = pd.read_csv('aries_crash_data_2017.csv')
raw_df.head()
# Out:
# /home/riggins/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (7,8,10,12,14,15,17,19,21,23,25,44,45,90,98) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    INDEXING_NUMBER  INDIVIDUAL_MR_RECORD  UNIT_MR_NUMBER STATUSCDE  PERSONNMB  \
# 0     902869479002             902869479               1        AC        2.0
# 1     902890114001             902890114               1        AC        1.0
# 2     902896591002             902896591               1        AC        2.0
# 3     902863058002             902863058               1        AC        2.0
# 4     902870589002             902870589               1        AC        2.0
#
#    PERSONTYPECDE PERSONTYPEDESCR GENDERCDE AGE_GRP  POSINVEHCDE  ...  \
# 0            5.0   Owner Vehicle       NaN     NaN          NaN  ...
# ...

# %% [markdown]
# # Filter Dataframe

# %%
raw_df['AGE_GRP'].value_counts()

# %%
raw_df['PERSONTYPEDESCR'].value_counts()

# %%
young = (raw_df['AGE_GRP'] == "<1 Year") | (raw_df['AGE_GRP'] == "1-4 Years") | (raw_df['AGE_GRP'] == "5-14 Years") | (raw_df['AGE_GRP'] == "15-24 Years")
on_street = (raw_df['PERSONTYPEDESCR'] == "Pedestrian") | (raw_df['PERSONTYPEDESCR'] == "Pedal Cyclist")

df = raw_df[young & on_street]
df.head()
# Out:
#         INDEXING_NUMBER  INDIVIDUAL_MR_RECORD  UNIT_MR_NUMBER STATUSCDE  \
# 231120     903036115001             903036115               3        AC
# 231128     902920859001             902920859               2        AC
# 231140     902981306001             902981306               2        AC
# 231141     903019794001             903019794               2        AC
# 231143     903014118001             903014118               2        AC
#
#         PERSONNMB  PERSONTYPECDE PERSONTYPEDESCR GENDERCDE      AGE_GRP  \
# 231120        1.0            3.0      Pedestrian         M   5-14 Years
# 231128        1.0            3.0      Pedestrian         F   5-14 Years
# 231140        1.0            4.0   Pedal Cyclist         M  15-24 Years
# 231141        1.0            3.0      Pedestrian         M  15-24 Years
# 231143        1.0            4.0   Pedal Cyclist         F  15-24 Years
#
#         POSINVEHCDE  ... TRAVDIRDESCR  EMGERENCY_RUN FIREIND  COLLEVENTCDE  \
# ...

# %%
c = pd.crosstab(df['AGE_GRP'], df['PERSONTYPEDESCR'], margins=True, margins_name="Total")
c = c.reindex(["<1 Year","1-4 Years","5-14 Years","15-24 Years","Total"], columns=["Pedestrian","Pedal Cyclist","Total"])
c
# Out:
# PERSONTYPEDESCR  Pedestrian  Pedal Cyclist  Total
# AGE_GRP
# <1 Year                   8              3     11
# 1-4 Years                35              1     36
# 5-14 Years              197            169    366
# 15-24 Years             355            251    606
# Total                   595            424   1019
